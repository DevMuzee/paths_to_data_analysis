# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sales=pd.read_excel(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\Website scraping prj\new file.xlsx")
sales
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2013-11-27   26  November  2015            19     Youth (<25)
# 2 2013-11-28   23     March  2014            49  Adults (35-64)
# 3 2013-11-29   23     March  2016            49  Adults (35-64)
# 4 2013-11-30   15       May  2014            47  Adults (35-64)
# 5 2013-12-01   15       May  2016            47  Adults (35-64)
# 6 2013-12-02   22       May  2014            47  Adults (35-64)
# 7 2013-12-03   22       May  2016            47  Adults (35-64)
# 8 2013-12-04   22  Febuaray  2014            35  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# ...

# %%
sales[0:4]
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2013-11-27   26  November  2015            19     Youth (<25)
# 2 2013-11-28   23     March  2014            49  Adults (35-64)
# 3 2013-11-29   23     March  2016            49  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              9 non-null      datetime64[ns]
#  1   Day               9 non-null      int64
#  2   Month             9 non-null      object
#  3   Year              9 non-null      int64
#  4   Customer_Age      9 non-null      int64
#  5   Age_Group         9 non-null      object
#  6   Customer_Gender   9 non-null      object
#  7   Country           9 non-null      object
#  8   State             9 non-null      object
#  9   Product_Category  9 non-null      object
#  10  Sub_Category      9 non-null      object
#  11  Product           9 non-null      object
#  12  Order_Quantity    9 non-null      int64
#  13  Unit_Cost         9 non-null      int64
#  14  Unit_Price        9 non-null      int64
#  15  Profit            9 non-null      int64
# ...

# %%
sales.describe()
# Out:
#                       Date        Day         Year  Customer_Age  \
# count                    9   9.000000     9.000000      9.000000
# mean   2013-11-30 00:00:00  21.555556  2014.666667     39.888889
# min    2013-11-26 00:00:00  15.000000  2013.000000     19.000000
# 25%    2013-11-28 00:00:00  22.000000  2014.000000     35.000000
# 50%    2013-11-30 00:00:00  22.000000  2014.000000     47.000000
# 75%    2013-12-02 00:00:00  23.000000  2016.000000     47.000000
# max    2013-12-04 00:00:00  26.000000  2016.000000     49.000000
# std                    NaN   4.034573     1.118034     12.574224
#
#        Order_Quantity  Unit_Cost  Unit_Price       Profit    Cost      Revenue
# count        9.000000        9.0         9.0     9.000000     9.0     9.000000
# mean        14.888889       45.0       120.0   629.333333   480.0  1111.333333
# min          4.000000       45.0       120.0   100.000000    90.0   190.000000
# ...

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2013-11-27   26  November  2015            19     Youth (<25)
# 2 2013-11-28   23     March  2014            49  Adults (35-64)
# 3 2013-11-29   23     March  2016            49  Adults (35-64)
# 4 2013-11-30   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales['Unit_Cost'].mean()
# Out:
# 45.0

# %%
sales['Unit_Cost'].describe()
# Out:
# count     9.0
# mean     45.0
# std       0.0
# min      45.0
# 25%      45.0
# 50%      45.0
# 75%      45.0
# max      45.0
# Name: Unit_Cost, dtype: float64

# %%
sales['Unit_Cost'].plot(kind='box', vert=False, figsize=(6,3))
# Out:
# <Axes: >

# %%
df=sales['Cost'].plot(kind='hist', figsize=(7,4), ylabel='Number of sales', xlabel='dollars')
df
# Out:
# <Axes: xlabel='dollars', ylabel='Number of sales'>

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2013-11-27   26  November  2015            19     Youth (<25)
# 2 2013-11-28   23     March  2014            49  Adults (35-64)
# 3 2013-11-29   23     March  2016            49  Adults (35-64)
# 4 2013-11-30   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales['Age_Group'].value_counts()
# Out:
# Age_Group
# Adults (35-64)    7
# Youth (<25)       2
# Name: count, dtype: int64

# %%
sales['Age_Group'].value_counts().plot(kind='pie', figsize=(3,3))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Age_Group'].value_counts().plot(kind='bar', ylabel='Number of sales', figsize=(3,3))
# Out:
# <Axes: xlabel='Age_Group', ylabel='Number of sales'>

# %%
sales.corr(numeric_only=True)
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.258639     -0.612154       -0.300160        NaN
# Year           -0.258639  1.000000      0.414935        0.421164        NaN
# Customer_Age   -0.612154  0.414935      1.000000        0.514153        NaN
# Order_Quantity -0.300160  0.421164      0.514153        1.000000        NaN
# Unit_Cost            NaN       NaN           NaN             NaN        NaN
# Unit_Price           NaN       NaN           NaN             NaN        NaN
# Profit          0.394417 -0.142652     -0.016884        0.056289        NaN
# Cost            0.315897 -0.131533      0.066273        0.045368        NaN
# Revenue         0.362009 -0.140159      0.021836        0.053580        NaN
#
#                 Unit_Price    Profit      Cost   Revenue
# Day                    NaN  0.394417  0.315897  0.362009
# Year                   NaN -0.142652 -0.131533 -0.140159
# ...

# %%
#draw an heat map for teh above

# %%
sales.plot(kind='scatter', x='Customer_Age', y='Revenue', figsize=(6,6))
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Revenue'>

# %%
sales[['Profit', 'Age_Group']].boxplot(by='Age_Group',figsize=(6,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sales[['Profit', 'Age_Group']].boxplot(by='Age_Group',figsize=(6,6))
#
# NameError: name 'sales' is not defined

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2013-11-27   26  November  2015            19     Youth (<25)
# 2 2013-11-28   23     March  2014            49  Adults (35-64)
# 3 2013-11-29   23     March  2016            49  Adults (35-64)
# 4 2013-11-30   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
col_need=['Year', 'Customer_Age','Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit' ]
sales[col_need].plot(kind='box',subplots=True, figsize=(14,8))
# Out:
# Year                 Axes(0.125,0.11;0.110714x0.77)
# Customer_Age      Axes(0.257857,0.11;0.110714x0.77)
# Order_Quantity    Axes(0.390714,0.11;0.110714x0.77)
# Unit_Cost         Axes(0.523571,0.11;0.110714x0.77)
# Unit_Price        Axes(0.656429,0.11;0.110714x0.77)
# Profit            Axes(0.789286,0.11;0.110714x0.77)
# dtype: object

# %%
sales['Revene_per_age']=sales['Revenue']/sales['Customer_Age']
sales.round().head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2013-11-27   26  November  2015            19     Youth (<25)
# 2 2013-11-28   23     March  2014            49  Adults (35-64)
# 3 2013-11-29   23     March  2016            49  Adults (35-64)
# 4 2013-11-30   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales['Revene_per_age'].plot(kind='density', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Calculated_cost']=sales['Order_Quantity'] * sales['Unit_Cost']
sales['Calculated_cost']
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2013-11-27   26  November  2015            19     Youth (<25)
# 2 2013-11-28   23     March  2014            49  Adults (35-64)
# 3 2013-11-29   23     March  2016            49  Adults (35-64)
# 4 2013-11-30   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales.plot(kind='scatter', x='Calculated_cost', y='Profit', figsize=(14,6))
# Out:
# <Axes: xlabel='Calculated_cost', ylabel='Profit'>

# %%
sales['Calculated_Revenue']=sales['Cost'] + sales['Profit']
sales['Calculated_Revenue']
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2013-11-27   26  November  2015            19     Youth (<25)
# 2 2013-11-28   23     March  2014            49  Adults (35-64)
# 3 2013-11-29   23     March  2016            49  Adults (35-64)
# 4 2013-11-30   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category  ...  \
# 0               M     Canada  British Columbia      Accessories  ...
# 1               M     Canada  British Columbia      Accessories  ...
# 2               M  Australia   New South Wales      Accessories  ...
# 3               M  Australia   New South Wales      Accessories  ...
# 4               F  Australia   New South Wales      Accessories  ...
#
#                Product Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike              8         45         120     590   360
# ...

# %%
sales['Unit_Price']*=1.03
sales['Unit_Price'].head()
# Out:
# 0    127.308
# 1    127.308
# 2    127.308
# 3    127.308
# 4    127.308
# Name: Unit_Price, dtype: float64

# %%
sales.loc[sales['State']=='British Columbia']
# Out:
#         Date  Day     Month  Year  Customer_Age    Age_Group Customer_Gender  \
# 0 2013-11-26   26  November  2013            19  Youth (<25)               M
# 1 2013-11-27   26  November  2015            19  Youth (<25)               M
#
#   Country             State Product_Category  ...              Product  \
# 0  Canada  British Columbia      Accessories  ...  Hitch Rack - 4-Bike
# 1  Canada  British Columbia      Accessories  ...  Hitch Rack - 4-Bike
#
#   Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue  \
# 0              8         45     127.308     590   360      950
# 1              8         45     127.308     590   360      950
#
#    Revene_per_age  Calculated_cost  Calculated_Revenue
# 0            50.0              360                 950
# 1            50.0              360                 950
#
# [2 rows x 21 columns]

# %%
sales.loc[sales['Age_Group']=='Adults (35-64)', 'Revenue'].mean()
# Out:
# 1157.4285714285713

# %%
sales.loc[(sales['Age_Group']=='Adults (35-64)') | (sales['Age_Group']=='Youth (<25)')].shape[0]
# Out:
# 9
