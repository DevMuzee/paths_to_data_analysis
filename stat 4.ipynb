# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\New_data_file\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
categorical=df.dtypes[df.dtypes=='object'].index
categorical
df[categorical].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# Questions to ask during data analysis are:
# 1. Do i need all of the variables

# %%
#df.drop(columns='PassengerId')
del df['PassengerId']

# %%
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
#sorting/checking the first 15 sorted names
#df['Name'].sort_values()[0:15]
sorted(df['Name'][0:15])
# Out:
# ['Allen, Mr. William Henry',
#  'Andersson, Mr. Anders Johan',
#  'Bonnell, Miss. Elizabeth',
#  'Braund, Mr. Owen Harris',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Heikkinen, Miss. Laina',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'McCarthy, Mr. Timothy J',
#  'Moran, Mr. James',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Palsson, Master. Gosta Leonard',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Saundercock, Mr. William Henry',
#  'Vestrom, Miss. Hulda Amanda Adolfina']

# %%
df['Name'].describe().to_frame()
# Out:
#                            Name
# count                       891
# unique                      891
# top     Braund, Mr. Owen Harris
# freq                          1

# %%
df['Ticket'][0:15]
# Out:
# 0            A/5 21171
# 1             PC 17599
# 2     STON/O2. 3101282
# 3               113803
# 4               373450
# 5               330877
# 6                17463
# 7               349909
# 8               347742
# 9               237736
# 10             PP 9549
# 11              113783
# 12           A/5. 2151
# 13              347082
# 14              350406
# Name: Ticket, dtype: object

# %%
df['Ticket'].describe()
# Out:
# count        891
# unique       681
# top       347082
# freq           7
# Name: Ticket, dtype: object

# %%
del df['Ticket']

# %%
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# ...

# %%
df['Cabin'][0:15]
# Out:
# 0      NaN
# 1      C85
# 2      NaN
# 3     C123
# 4      NaN
# 5      NaN
# 6      E46
# 7      NaN
# 8      NaN
# 9      NaN
# 10      G6
# 11    C103
# 12     NaN
# 13     NaN
# 14     NaN
# Name: Cabin, dtype: object

# %%
df['Cabin'].describe()
# Out:
# count         204
# unique        147
# top       B96 B98
# freq            4
# Name: Cabin, dtype: object

# %%
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# ...

# %% [markdown]
# 2. SHOULD I TRANSFORM ANY VARIABLE

# %%
new_cat=pd.Categorical(df['Survived'])
new_cat=new_cat.rename_categories(['Died', 'Survived'])
new_cat.describe()
# Out:
#             counts     freqs
# categories
# Died           549  0.616162
# Survived       342  0.383838

# %%
new_Pclass=pd.Categorical(df['Pclass'], ordered=True)
new_Pclass=new_cat.rename_categories(['Class1', 'Class2', 'Class3'])
new_Pclass.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 new_Pclass=pd.Categorical(df['Pclass'], ordered=True)
# ----> 2 new_Pclass=new_cat.rename_categories(['Class1', 'Class2', 'Class3'])
#       3 new_Pclass.describe()
#
# File C:\Anaconda\Lib\site-packages\pandas\core\arrays\categorical.py:979, in Categorical.rename_categories(self, new_categories)
#     976     new_categories = [new_categories(item) for item in self.categories]
#     978 cat = self.copy()
# --> 979 cat._set_categories(new_categories)
#     980 return cat
#
# File C:\Anaconda\Lib\site-packages\pandas\core\arrays\categorical.py:783, in Categorical._set_categories(self, categories, fastpath)
#     777     new_dtype = CategoricalDtype(categories, ordered=self.ordered)
#     778 if (
#     779     not fastpath
#     780     and self.dtype.categories is not None
# ...

# %%
df['Pclass']=new_Pclass

# %%
df['Cabin'].unique()

# %%
new_char=df['Cabin'].astype(str) #convert to string
first_value=np.array([cabin[0] for cabin in new_char]) #getting teh first letter
first_value=pd.Categorical(first_value)

first_value.describe()
# Out:
#             counts     freqs
# categories
# A               15  0.016835
# B               47  0.052750
# C               59  0.066218
# D               33  0.037037
# E               32  0.035915
# F               13  0.014590
# G                4  0.004489
# T                1  0.001122
# n              687  0.771044

# %%
df['Cabin']=first_value

# %% [markdown]
# 3. Are there NA values, outliers or other string values

# %%
df['Age'].describe().to_frame()
# Out:
#               Age
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000

# %%
missing_value=np.where(df['Age'].isnull()==True)
missing_value #to locate the index positionsof where the null values are True
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
len(missing_value[0])# the total lenght of the null values
# Out:
# 177

# %%
df['Age'].plot(kind='hist', figsize=(9,6), bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
new_age_var=np.where(df['Age'].isnull,
                    28,
                     df['Age'])#replacing teh missing value with median=28
df['Age']=new_age_var
df['Age'].describe()
# Out:
# count    891.0
# mean      28.0
# std        0.0
# min       28.0
# 25%       28.0
# 50%       28.0
# 75%       28.0
# max       28.0
# Name: Age, dtype: float64

# %%
#search for outliers (extreme values)
df.head(5)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0  Class3                            Braund, Mr. Owen Harris
# 1         1  Class1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1  Class3                             Heikkinen, Miss. Laina
# 3         1  Class1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0  Class3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  28.0      1      0   7.2500     n        S
# 1  female  28.0      1      0  71.2833     C        C
# 2  female  28.0      0      0   7.9250     n        S
# 3  female  28.0      1      0  53.1000     C        S
# 4    male  28.0      0      0   8.0500     n        S

# %%
df['Fare'].plot(kind='box', figsize=(9,9))
# Out:
# <Axes: >

# %%
#max_payer=np.where(df['Fare']==max(df['Fare']))
df.loc[df['Fare']==max(df['Fare'])]
# Out:
#      Survived  Pclass                                Name     Sex   Age  \
# 258         1  Class1                    Ward, Miss. Anna  female  28.0
# 679         1  Class1  Cardeza, Mr. Thomas Drake Martinez    male  28.0
# 737         1  Class1              Lesurer, Mr. Gustave J    male  28.0
#
#      SibSp  Parch      Fare Cabin Embarked
# 258      0      0  512.3292     n        C
# 679      0      1  512.3292     B        C
# 737      0      0  512.3292     B        C

# %% [markdown]
# 4. Should i create a new variable

# %%
df['Family']=df['SibSp']+df['Parch']

# %%
most_family=df.loc[df['Family']==max(df['Family'])]
most_family
# Out:
#      Survived  Pclass                               Name     Sex   Age  SibSp  \
# 159         0  Class3         Sage, Master. Thomas Henry    male  28.0      8
# 180         0  Class3       Sage, Miss. Constance Gladys  female  28.0      8
# 201         0  Class3                Sage, Mr. Frederick    male  28.0      8
# 324         0  Class3           Sage, Mr. George John Jr    male  28.0      8
# 792         0  Class3            Sage, Miss. Stella Anna  female  28.0      8
# 846         0  Class3           Sage, Mr. Douglas Bullen    male  28.0      8
# 863         0  Class3  Sage, Miss. Dorothy Edith "Dolly"  female  28.0      8
#
#      Parch   Fare Cabin Embarked  Family
# 159      2  69.55     n        S      10
# 180      2  69.55     n        S      10
# 201      2  69.55     n        S      10
# 324      2  69.55     n        S      10
# 792      2  69.55     n        S      10
# 846      2  69.55     n        S      10
# 863      2  69.55     n        S      10
