# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\Website scraping prj\sales_rep.xlsx")
df
# Out:
#    Unnamed: 0       Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0           0 2013-11-26   26  November  2013            19     Youth (<25)
# 1           1 2015-11-26   26  November  2015            19     Youth (<25)
# 2           2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3           3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4           4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df=df.drop(columns='Unnamed: 0')
df
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# The mean of the customer ages

# %%
df1=df.set_index('Date')
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df1['Customer_Age'].mean()
# Out:
# 36.6

# %%
df1['Customer_Age'].plot(kind='kde', figsize=(5,2))
# Out:
# <Axes: ylabel='Density'>

# %%
df1['Customer_Age'].plot(kind='box', figsize=(5,2))
# Out:
# <Axes: >

# %% [markdown]
# The mean of the Order_Quantity

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df1['Order_Quantity'].mean()
# Out:
# 12.6

# %%
df1.plot(kind='hist', bins=30, figsize=(14, 6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind='box', figsize=(14, 6))
# Out:
# <Axes: >

# %% [markdown]
# How many sales per year do we have then draw a pie plot

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df['Customer_Age'].value_counts()
# Out:
# Customer_Age
# 19    2
# 49    2
# 47    1
# Name: count, dtype: int64

# %%
df2=df1['Year'].value_counts()
df2
# Out:
# Year
# 2014    2
# 2013    1
# 2015    1
# 2016    1
# Name: count, dtype: int64

# %%
df2.plot(kind='pie', figsize=(10,3))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Sales per month

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df3=df1['Month'].value_counts()
df3
# Out:
# Month
# November    2
# March       2
# May         1
# Name: count, dtype: int64

# %%
df3.plot(kind='bar', figsize=(7,3))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Country with the most sales (QUANTITY OF SALES)

# %%
df4=df1['Country'].value_counts().head(1)
df4.plot(kind='bar', figsize=(5,2))
# Out:
# <Axes: xlabel='Country'>

# %%
df5=df1['Country'].value_counts().head()
df5.plot(kind='bar', figsize=(7,4))
# Out:
# <Axes: xlabel='Country'>

# %% [raw]
# Create a list of every product sold

# %%
df5=df1['Product'].unique()
df5
# Out:
# array(['Hitch Rack - 4-Bike'], dtype=object)

# %%
df1['Product'].value_counts().head(1).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df1.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(5,1))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %% [raw]
# Relationship between profit per country

# %%
df1[['Profit', 'Country']].boxplot(by='Country', figsize=(7,4))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %%
df1[['Customer_Age', 'Country']].boxplot(by='Country')
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %% [markdown]
# Add and calculate a new Calculated_Date column

# %%
df1['calculated_date_column']=df1[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df1['calculated_date_column']=pd.to_datetime(df1['calculated_date_column'])
df1['calculated_date_column']
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df1['calculated_date_column'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='calculated_date_column'>

# %%
df2['count_of_sales']=df1['Year'].value_counts()
df2['count_of_sales']
# Out:
# Year
# 2014    2
# 2013    1
# 2015    1
# 2016    1
# Name: count, dtype: int64

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %% [raw]
# orders made in canada or france

# %%
df1.loc[(df1['Country'] == 'Canada') | (df1['Country']=='Australia')].shape[0]
# Out:
# 5

# %%
df1.loc[(df1['Country']=='Canada') & (df1['Sub_Category']=='Bike Racks')].shape[0]   #Bike Racks orders were made from Canada?
# Out:
# 2

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %% [markdown]
# How many orders were made in each region (state) of Australia

# %%
Australia_state=df1.loc[df1['Country']=='Australia','State'].value_counts()
Australia_state
# Out:
# State
# New South Wales    3
# Name: count, dtype: int64

# %%
Australia_state.plot.barh(figsize=(7,4))
# Out:
# <Axes: ylabel='State'>

# %% [markdown]
# How many sales were made per category?

# %%
df1['Product_Category'].value_counts().plot(kind='bar', figsize=(3,3))
# Out:
# <Axes: xlabel='Product_Category'>

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %% [markdown]
# How many orders were made per accessory sub-categories?

# %%
accessories=df1.loc[df1['Product_Category']=='Accessories','Sub_Category'].value_counts()
accessories
# Out:
# Sub_Category
# Bike Racks    5
# Name: count, dtype: int64

# %%
accessories=df1.loc[df1['Product_Category']=='Accessories','Sub_Category'].value_counts().plot(kind='bar', figsize=(3,3))
accessories
# Out:
# <Axes: xlabel='Sub_Category'>

# %% [markdown]
# How many orders were made per bike sub-categories?

# %%
bikes=df1.loc[df1['Product_Category']=='Bike Racks','Sub_Category'].value_counts()
bikes
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# Which gender has the most amount of sales?

# %%
df1['Customer_Gender'].value_counts().head(1)
# Out:
# Customer_Gender
# M    4
# Name: count, dtype: int64

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %% [markdown]
# How many sales with more than 500 in Revenue were made by men?

# %%
df1.loc[(df1['Customer_Gender']=='M') & (df1['Revenue']>= 500)].shape[0]
# Out:
# 4

# %%
df1['Revenue'].value_counts(ascending=True).head(5)
# Out:
# Revenue
# 2401    1
# 2088    1
# 418     1
# 950     2
# Name: count, dtype: int64

# %%
df1.sort_values(['Revenue'], ascending=False).head(5) #Get the top-5 sales with the highest revenue
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %% [markdown]
# sales with the highest revenue

# %%
df1['Revenue'].value_counts(ascending=True).head(1)
# Out:
# Revenue
# 2401    1
# Name: count, dtype: int64

# %%
df1.sort_values(['Revenue'], ascending=False).head(1)
# Out:
#             Day  Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2014-03-23   23  March  2014            49  Adults (35-64)               M
#
#               Country            State Product_Category Sub_Category  \
# Date
# 2014-03-23  Australia  New South Wales      Accessories   Bike Racks
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# Date
# 2014-03-23  Hitch Rack - 4-Bike              23         45         120
#
#             Profit  Cost  Revenue calculated_date_column
# Date
# 2014-03-23    1366  1035     2401             2014-03-23

# %%
maximum=df1['Revenue']==df1['Revenue'].max()
maximum
# Out:
# Date
# 2013-11-26    False
# 2015-11-26    False
# 2014-03-23     True
# 2016-03-23    False
# 2014-05-15    False
# Name: Revenue, dtype: bool

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %% [markdown]
# What is the mean Order_Quantity of orders with more than and less than 10K in revenue?

# %%
cond=df1['Revenue']>=1000 # more than
df1.loc[cond, 'Order_Quantity'].mean()
# Out:
# 21.5

# %%
df1.loc[(df1['Revenue']>=500), 'Order_Quantity'].mean()
# Out:
# 14.75

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
lesser=df1.loc[(df1['Revenue']<=1000), 'Order_Quantity'].mean()#lesser than 1k 
lesser.round()
# Out:
# 7.0

# %% [markdown]
# How many orders were made in May of 2016?

# %%
orders=df1.loc[(df1['Year']==2016) & (df1['Month']=='May')].shape[0]
orders
# Out:
# 0

# %% [markdown]
# How many orders were made between May and July of 2016?

# %%
sales_made=df1.loc[(df1['Year']==2016) & (df1['Month'].isin(['May', 'June', 'July']))].shape[0]
sales_made
# Out:
# 0

# %% [markdown]
# Show a grouped box plot per month with the profit values.

# %%
grouped=df1.loc[df1['Year']==2016, ['Profit', 'Month']]
grouped.boxplot(figsize=(3,4))
# Out:
# <Axes: >

# %% [markdown]
# Add 7.2% TAX on every sale Unit_Price within United States

# %%
df1['tax']=df1.loc[df1['State']=='New South Wales', 'Unit_Price']*0.072
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df1
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...
