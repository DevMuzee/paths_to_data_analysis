# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ABDULMUIZ AKOREDE\Downloads\Breast Cancer METABRIC.csv")
df.head(3)
# Out:
#   Patient ID  Age at Diagnosis Type of Breast Surgery    Cancer Type  \
# 0    MB-0000             75.65             Mastectomy  Breast Cancer
# 1    MB-0002             43.19      Breast Conserving  Breast Cancer
# 2    MB-0005             48.87             Mastectomy  Breast Cancer
#
#                Cancer Type Detailed Cellularity Chemotherapy  \
# 0  Breast Invasive Ductal Carcinoma         NaN           No
# 1  Breast Invasive Ductal Carcinoma        High           No
# 2  Breast Invasive Ductal Carcinoma        High          Yes
#
#   Pam50 + Claudin-low subtype  Cohort ER status measured by IHC  ...  \
# 0                 claudin-low     1.0                   Positve  ...
# 1                        LumA     1.0                   Positve  ...
# 2                        LumB     1.0                   Positve  ...
#
#   Overall Survival Status  PR Status Radio Therapy  \
# 0                  Living   Negative           Yes
# 1                  Living   Positive           Yes
# ...

# %%
pd.set_option('display.max.columns',34 )

# %%
df2=df[['Patient ID', 'Age at Diagnosis', 'Type of Breast Surgery', 'Cancer Type Detailed',
  'Chemotherapy', 'Hormone Therapy', 'Radio Therapy', 'Patient\'s Vital Status']]
df2
# Out:
#      Patient ID  Age at Diagnosis Type of Breast Surgery  \
# 0       MB-0000             75.65             Mastectomy
# 1       MB-0002             43.19      Breast Conserving
# 2       MB-0005             48.87             Mastectomy
# 3       MB-0006             47.68             Mastectomy
# 4       MB-0008             76.97             Mastectomy
# ...         ...               ...                    ...
# 2504  MTS-T2428             70.05                    NaN
# 2505  MTS-T2429             63.60                    NaN
# 2506  MTS-T2430               NaN                    NaN
# 2507  MTS-T2431               NaN                    NaN
# 2508  MTS-T2432               NaN                    NaN
#
#                            Cancer Type Detailed Chemotherapy Hormone Therapy  \
# 0              Breast Invasive Ductal Carcinoma           No             Yes
# 1              Breast Invasive Ductal Carcinoma           No             Yes
# ...

# %%
df2.head(7)
# Out:
#   Patient ID  Age at Diagnosis Type of Breast Surgery  \
# 0    MB-0000             75.65             Mastectomy
# 1    MB-0002             43.19      Breast Conserving
# 2    MB-0005             48.87             Mastectomy
# 3    MB-0006             47.68             Mastectomy
# 4    MB-0008             76.97             Mastectomy
# 5    MB-0010             78.77             Mastectomy
# 6    MB-0014             56.45      Breast Conserving
#
#                         Cancer Type Detailed Chemotherapy Hormone Therapy  \
# 0           Breast Invasive Ductal Carcinoma           No             Yes
# 1           Breast Invasive Ductal Carcinoma           No             Yes
# 2           Breast Invasive Ductal Carcinoma          Yes             Yes
# 3  Breast Mixed Ductal and Lobular Carcinoma          Yes             Yes
# 4  Breast Mixed Ductal and Lobular Carcinoma          Yes             Yes
# 5           Breast Invasive Ductal Carcinoma           No             Yes
# ...

# %%
df['Chemotherapy'].value_counts()
# Out:
# Chemotherapy
# No     1568
# Yes     412
# Name: count, dtype: int64

# %%
df['Hormone Therapy'].value_counts()
# Out:
# Hormone Therapy
# Yes    1216
# No      764
# Name: count, dtype: int64

# %%
df['Radio Therapy'].value_counts()
# Out:
# Radio Therapy
# Yes    1173
# No      807
# Name: count, dtype: int64

# %%
df5=df[['Chemotherapy', 'Hormone Therapy', 'Radio Therapy']].value_counts().to_frame()
df5.to_csv(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\New_data_file\three_files.csv")

# %%
pd.crosstab(index=df['Patient\'s Vital Status'],
           columns='counts')
# Out:
# col_0                   counts
# Patient's Vital Status
# Died of Disease            646
# Died of Other Causes       497
# Living                     837

# %%
df3=pd.crosstab(index=df['Patient\'s Vital Status'],
           columns=[df['Hormone Therapy'],
                    df['Chemotherapy'],
                    df['Radio Therapy']],
            margins=True
                    )
df3
# Out:
# Hormone Therapy          No                Yes                 All
# Chemotherapy             No      Yes        No      Yes
# Radio Therapy            No  Yes  No  Yes   No  Yes  No  Yes
# Patient's Vital Status
# Died of Disease          85   53  29   90  125  183  17   64   646
# Died of Other Causes    104   55   2    7  150  164   2   12   496
# Living                  122  123  17   76  144  259  10   86   837
# All                     311  231  48  173  419  606  29  162  1979

# %%
df3.to_csv(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\New_data_file\Homo_chemo_rad.csv")

# %%
pd.crosstab(index=df['Relapse Free Status'],
            columns='Counts')
# Out:
# col_0                Counts
# Relapse Free Status
# Not Recurred           1486
# Recurred               1002

# %%
df4=pd.crosstab(index=df['Relapse Free Status'],
           columns=[df['Hormone Therapy'],
                    df['Chemotherapy'],
                    df['Radio Therapy']],
            margins=True
                    )
df4
# Out:
# Hormone Therapy       No                Yes                 All
# Chemotherapy          No      Yes        No      Yes
# Radio Therapy         No  Yes  No  Yes   No  Yes  No  Yes
# Relapse Free Status
# Not Recurred         194  154  18   79  265  373   9   84  1176
# Recurred             117   77  30   94  154  233  20   78   803
# All                  311  231  48  173  419  606  29  162  1979

# %%
df4=pd.crosstab(index=[df['Relapse Free Status'],
                      df['Overall Survival Status'],
                      df['Patient\'s Vital Status']],
           columns=[df['Hormone Therapy'],
                    df['Chemotherapy'],
                    df['Radio Therapy']],
                
                    )
df4.to_csv(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\New_data_file\crosstab.csv")

# %%
df5=df[['Chemotherapy', 'Hormone Therapy', 'Radio Therapy', 'Patient\'s Vital Status']].value_counts().to_frame()
df5
# Out:
#                                                                    count
# Chemotherapy Hormone Therapy Radio Therapy Patient's Vital Status
# No           Yes             Yes           Living                    259
#                                            Died of Disease           183
#                                            Died of Other Causes      164
#                              No            Died of Other Causes      150
#                                            Living                    144
#                                            Died of Disease           125
#              No              Yes           Living                    123
#                              No            Living                    122
#                                            Died of Other Causes      104
# Yes          No              Yes           Died of Disease            90
#              Yes             Yes           Living                     86
# ...
