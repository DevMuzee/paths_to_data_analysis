# %%
import pandas as pd

# %%
df1=pd.read_csv(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\Website scraping prj\Book2.csv")
df1
# Out:
#    Unnamed: 0  Rank             Name                 Industry  \
# 0           0     2        Microsoft               Technology
# 1           1     3         Alphabet               Technology
# 2           2     8           Pfizer  Pharmaceutical industry
# 3           3     9  Bank of America               Financials
# 4           4    10   Meta Platforms               Technology
#
#   Profits(USD millions)
# 0            $72,738.00
# 1            $59,972.00
# 2            $31,372.00
# 3            $27,528.00
# 4            $23,200.00

# %%
df2=pd.read_csv(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\Website scraping prj\Book3.csv")
df2
# Out:
#    Unnamed: 0  Rank            Name            Industry Profits(USD millions)
# 0           0     2       Microsoft          Technology            $72,738.00
# 1           1     3        Alphabet          Technology            $59,972.00
# 2           2     5      ExxonMobil  Petroleum industry            $55,740.00
# 3           3     6  JPMorgan Chase          Financials            $37,676.00

# %%
df1.merge(df2, how='inner')
# Out:
#    Unnamed: 0  Rank       Name    Industry Profits(USD millions)
# 0           0     2  Microsoft  Technology            $72,738.00
# 1           1     3   Alphabet  Technology            $59,972.00

# %%
df1.merge(df2, how='outer')
# Out:
#    Unnamed: 0  Rank             Name                 Industry  \
# 0           0     2        Microsoft               Technology
# 1           1     3         Alphabet               Technology
# 2           2     8           Pfizer  Pharmaceutical industry
# 3           3     9  Bank of America               Financials
# 4           4    10   Meta Platforms               Technology
# 5           2     5       ExxonMobil       Petroleum industry
# 6           3     6   JPMorgan Chase               Financials
#
#   Profits(USD millions)
# 0            $72,738.00
# 1            $59,972.00
# 2            $31,372.00
# 3            $27,528.00
# 4            $23,200.00
# 5            $55,740.00
# 6            $37,676.00

# %%
df1.merge(df2, how='left')
# Out:
#    Unnamed: 0  Rank             Name                 Industry  \
# 0           0     2        Microsoft               Technology
# 1           1     3         Alphabet               Technology
# 2           2     8           Pfizer  Pharmaceutical industry
# 3           3     9  Bank of America               Financials
# 4           4    10   Meta Platforms               Technology
#
#   Profits(USD millions)
# 0            $72,738.00
# 1            $59,972.00
# 2            $31,372.00
# 3            $27,528.00
# 4            $23,200.00

# %%
df1.merge(df2, how='right')
# Out:
#    Unnamed: 0  Rank            Name            Industry Profits(USD millions)
# 0           0     2       Microsoft          Technology            $72,738.00
# 1           1     3        Alphabet          Technology            $59,972.00
# 2           2     5      ExxonMobil  Petroleum industry            $55,740.00
# 3           3     6  JPMorgan Chase          Financials            $37,676.00

# %%
df1.merge(df2, how='cross')
# Out:
#     Unnamed: 0_x  Rank_x           Name_x               Industry_x  \
# 0              0       2        Microsoft               Technology
# 1              0       2        Microsoft               Technology
# 2              0       2        Microsoft               Technology
# 3              0       2        Microsoft               Technology
# 4              1       3         Alphabet               Technology
# 5              1       3         Alphabet               Technology
# 6              1       3         Alphabet               Technology
# 7              1       3         Alphabet               Technology
# 8              2       8           Pfizer  Pharmaceutical industry
# 9              2       8           Pfizer  Pharmaceutical industry
# 10             2       8           Pfizer  Pharmaceutical industry
# 11             2       8           Pfizer  Pharmaceutical industry
# 12             3       9  Bank of America               Financials
# ...

# %% [raw]
# CONCATENATE FUNCTION

# %%
pd.concat([df1, df2], join='inner', axis=1)
# Out:
#    Unnamed: 0  Rank             Name                 Industry  \
# 0           0     2        Microsoft               Technology
# 1           1     3         Alphabet               Technology
# 2           2     8           Pfizer  Pharmaceutical industry
# 3           3     9  Bank of America               Financials
#
#   Profits(USD millions)  Unnamed: 0  Rank            Name            Industry  \
# 0            $72,738.00           0     2       Microsoft          Technology
# 1            $59,972.00           1     3        Alphabet          Technology
# 2            $31,372.00           2     5      ExxonMobil  Petroleum industry
# 3            $27,528.00           3     6  JPMorgan Chase          Financials
#
#   Profits(USD millions)
# 0            $72,738.00
# 1            $59,972.00
# 2            $55,740.00
# 3            $37,676.00

# %%
pd.concat([df1, df2], join='inner', axis=0)
# Out:
#    Unnamed: 0  Rank             Name                 Industry  \
# 0           0     2        Microsoft               Technology
# 1           1     3         Alphabet               Technology
# 2           2     8           Pfizer  Pharmaceutical industry
# 3           3     9  Bank of America               Financials
# 4           4    10   Meta Platforms               Technology
# 0           0     2        Microsoft               Technology
# 1           1     3         Alphabet               Technology
# 2           2     5       ExxonMobil       Petroleum industry
# 3           3     6   JPMorgan Chase               Financials
#
#   Profits(USD millions)
# 0            $72,738.00
# 1            $59,972.00
# 2            $31,372.00
# 3            $27,528.00
# 4            $23,200.00
# 0            $72,738.00
# 1            $59,972.00
# 2            $55,740.00
# 3            $37,676.00
