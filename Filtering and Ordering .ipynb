# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\Website scraping prj\Book1.xlsx")

# %%
df
# Out:
#      Rank                      Name                    Industry  \
# 0     100                  Qualcomm                  Technology
# 1       1                   Walmart                      Retail
# 2       2                    Amazon  Retail and cloud computing
# 3       3                ExxonMobil          Petroleum industry
# 4       4                     Apple        Electronics industry
# ..    ...                       ...                         ...
# 196    96                  Best Buy                      Retail
# 197    97      Bristol-Myers Squibb     Pharmaceutical industry
# 198    98           United Airlines                     Airline
# 199    99  Thermo Fisher Scientific      Laboratory instruments
# 200   100                  Qualcomm                  Technology
#
#      Revenue (USD millions)  Revenue growth Employees             Headquarters
# 0                     44200           0.317     51000    San Diego, California
# ...

# %% [markdown]
# FILTERING

# %%
df[df['Rank']<=4]
# Out:
#      Rank        Name                    Industry  Revenue (USD millions)  \
# 1       1     Walmart                      Retail                  611289
# 2       2      Amazon  Retail and cloud computing                  513983
# 3       3  ExxonMobil          Petroleum industry                  413680
# 4       4       Apple        Electronics industry                  394328
# 101     1     Walmart                      Retail                  611289
# 102     2      Amazon  Retail and cloud computing                  513983
# 103     3  ExxonMobil          Petroleum industry                  413680
# 104     4       Apple        Electronics industry                  394328
#
#      Revenue growth Employees           Headquarters
# 1             0.067   2100000  Bentonville, Arkansas
# 2             0.094   1540000    Seattle, Washington
# 3             0.448     62000          Spring, Texas
# 4             0.078    164000  Cupertino, California
# ...

# %%
specific_industry=['Retail']
df[df['Industry'].isin(specific_industry)]
# Out:
#      Rank                Name Industry  Revenue (USD millions)  \
# 1       1             Walmart   Retail                  611289
# 12     12              Costco   Retail                  226954
# 20     20      The Home Depot   Retail                  157403
# 24     24              Kroger   Retail                  148258
# 33     33  Target Corporation   Retail                  109120
# 39     39              Lowe's   Retail                   97059
# 53     53          Albertsons   Retail                   77650
# 80     80              Publix   Retail                   54942
# 89     89                 TJX   Retail                   49936
# 96     96            Best Buy   Retail                   46298
# 101     1             Walmart   Retail                  611289
# 112    12              Costco   Retail                  226954
# 120    20      The Home Depot   Retail                  157403
# 124    24              Kroger   Retail                  148258
# ...

# %%
df[df['Headquarters'].str.contains('Irving')]
# Out:
#      Rank                  Name Industry  Revenue (USD millions)  \
# 9       9  McKesson Corporation   Health                  276711
# 109     9  McKesson Corporation   Health                  276711
#
#      Revenue growth Employees   Headquarters
# 9             0.048     48500  Irving, Texas
# 109           0.048     48500  Irving, Texas

# %%
df2=df.set_index('Name')
df2
# Out:
#                           Rank                    Industry  \
# Name
# Qualcomm                   100                  Technology
# Walmart                      1                      Retail
# Amazon                       2  Retail and cloud computing
# ExxonMobil                   3          Petroleum industry
# Apple                        4        Electronics industry
# ...                        ...                         ...
# Best Buy                    96                      Retail
# Bristol-Myers Squibb        97     Pharmaceutical industry
# United Airlines             98                     Airline
# Thermo Fisher Scientific    99      Laboratory instruments
# Qualcomm                   100                  Technology
#
#                           Revenue (USD millions)  Revenue growth Employees  \
# Name
# Qualcomm                                   44200           0.317     51000
# Walmart                                   611289           0.067   2100000
# ...

# %%
df2.filter(items=['Industry', 'Revenue growth'])
# Out:
#                                             Industry  Revenue growth
# Name
# Qualcomm                                  Technology           0.317
# Walmart                                       Retail           0.067
# Amazon                    Retail and cloud computing           0.094
# ExxonMobil                        Petroleum industry           0.448
# Apple                           Electronics industry           0.078
# ...                                              ...             ...
# Best Buy                                      Retail           0.106
# Bristol-Myers Squibb         Pharmaceutical industry           0.005
# United Airlines                              Airline           0.825
# Thermo Fisher Scientific      Laboratory instruments           0.145
# Qualcomm                                  Technology           0.317
#
# [201 rows x 2 columns]

# %%
df2[df['Name'].str.contains('Qualcomm')]
# Out:
# C:\Users\ABDULMUIZ AKOREDE\AppData\Local\Temp\ipykernel_5580\1239443879.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2[df['Name'].str.contains('Qualcomm')]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df2[df['Name'].str.contains('Qualcomm')]
#
# File C:\Anaconda\Lib\site-packages\pandas\core\frame.py:3752, in DataFrame.__getitem__(self, key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
# -> 3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#    3756 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# ...

# %%
df2.filter(like='Qualcomm', axis=0)
# Out:
#           Rank    Industry  Revenue (USD millions)  Revenue growth Employees  \
# Name
# Qualcomm   100  Technology                   44200           0.317     51000
# Qualcomm   100  Technology                   44200           0.317     51000
# Qualcomm   100  Technology                   44200           0.317     51000
#
#                    Headquarters
# Name
# Qualcomm  San Diego, California
# Qualcomm  San Diego, California
# Qualcomm  San Diego, California

# %%
df2.iloc[2]
# Out:
# Rank                                               2
# Industry                  Retail and cloud computing
# Revenue (USD millions)                        513983
# Revenue growth                                 0.094
# Employees                                    1540000
# Headquarters                     Seattle, Washington
# Name: Amazon, dtype: object

# %% [markdown]
# Ordering

# %%
df
# Out:
#      Rank                      Name                    Industry  \
# 0     100                  Qualcomm                  Technology
# 1       1                   Walmart                      Retail
# 2       2                    Amazon  Retail and cloud computing
# 3       3                ExxonMobil          Petroleum industry
# 4       4                     Apple        Electronics industry
# ..    ...                       ...                         ...
# 196    96                  Best Buy                      Retail
# 197    97      Bristol-Myers Squibb     Pharmaceutical industry
# 198    98           United Airlines                     Airline
# 199    99  Thermo Fisher Scientific      Laboratory instruments
# 200   100                  Qualcomm                  Technology
#
#      Revenue (USD millions)  Revenue growth Employees             Headquarters
# 0                     44200           0.317     51000    San Diego, California
# ...

# %%
df[df['Rank']<10].sort_values(by=['Rank', 'Industry'], ascending=[False, True])
# Out:
#      Rank                  Name                        Industry  \
# 9       9  McKesson Corporation                          Health
# 109     9  McKesson Corporation                          Health
# 8       8              Alphabet  Technology and cloud computing
# 108     8              Alphabet  Technology and cloud computing
# 7       7    Berkshire Hathaway                    Conglomerate
# 107     7    Berkshire Hathaway                    Conglomerate
# 6       6            CVS Health                      Healthcare
# 106     6            CVS Health                      Healthcare
# 5       5    UnitedHealth Group                      Healthcare
# 105     5    UnitedHealth Group                      Healthcare
# 4       4                 Apple            Electronics industry
# 104     4                 Apple            Electronics industry
# 3       3            ExxonMobil              Petroleum industry
# 103     3            ExxonMobil              Petroleum industry
# ...
