# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\ABDULMUIZ AKOREDE\Documents\Project.py\Website scraping prj\Hockey.xlsx")

# %%
df
# Out:
#                 Team Name  Year  Wins  Losses  OT Losses  Win %  \
# 0           Boston Bruins  1990    44      24        NaN  0.550
# 1          Buffalo Sabres  1990    31      30        NaN  0.388
# 2          Calgary Flames  1990    46      26        NaN  0.575
# 3      Chicago Blackhawks  1990    49      23        NaN  0.613
# 4       Detroit Red Wings  1990    34      38        NaN  0.425
# 5         Edmonton Oilers  1990    37      37        NaN  0.463
# 6        Hartford Whalers  1990    31      38        NaN  0.388
# 7       Los Angeles Kings  1990    46      24        NaN  0.575
# 8   Minnesota North Stars  1990    27      39        NaN  0.338
# 9      Montreal Canadiens  1990    39      30        NaN  0.487
# 10      New Jersey Devils  1990    32      33        NaN  0.400
# 11     New York Islanders  1990    25      45        NaN  0.312
# 12       New York Rangers  1990    36      31        NaN  0.450
# 13    Philadelphia Flyers  1990    33      37        NaN  0.412
# ...

# %%
df.tail()
# Out:
#              Team Name  Year  Wins  Losses  OT Losses  Win %  Goals For (GF)  \
# 45       Winnipeg Jets  1990    26      43        NaN  0.325             260
# 46       Boston Bruins  1991    36      32        NaN  0.450             270
# 47      Buffalo Sabres  1991    31      37        NaN  0.388             289
# 48      Calgary Flames  1991    31      37        NaN  0.388             296
# 49  Chicago Blackhawks  1991    36      29        NaN  0.450             257
#
#     Goals Against (GA)  + / -
# 45                 288    -28
# 46                 275     -5
# 47                 299    -10
# 48                 305     -9
# 49                 236     21

# %%
df[df['Wins']<=20]
# Out:
#            Team Name  Year  Wins  Losses  OT Losses  Win %  Goals For (GF)  \
# 15  Quebec Nordiques  1990    16      50        NaN    0.2             236
# 40  Quebec Nordiques  1990    16      50        NaN    0.2             236
#
#     Goals Against (GA)  + / -
# 15                 354   -118
# 40                 354   -118

# %%
team_name=['Buffalo Sabres', 'Calgary Flames']
df[df['Team Name'].isin(team_name)]
# Out:
#          Team Name  Year  Wins  Losses  OT Losses  Win %  Goals For (GF)  \
# 1   Buffalo Sabres  1990    31      30        NaN  0.388             292
# 2   Calgary Flames  1990    46      26        NaN  0.575             344
# 22  Buffalo Sabres  1991    31      37        NaN  0.388             289
# 23  Calgary Flames  1991    31      37        NaN  0.388             296
# 26  Buffalo Sabres  1990    31      30        NaN  0.388             292
# 27  Calgary Flames  1990    46      26        NaN  0.575             344
# 47  Buffalo Sabres  1991    31      37        NaN  0.388             289
# 48  Calgary Flames  1991    31      37        NaN  0.388             296
#
#     Goals Against (GA)  + / -
# 1                  278     14
# 2                  263     81
# 22                 299    -10
# 23                 305     -9
# 26                 278     14
# 27                 263     81
# 47                 299    -10
# 48                 305     -9

# %%
df[df['Team Name'].str.contains('Calgary Flames')]
# Out:
#          Team Name  Year  Wins  Losses  OT Losses  Win %  Goals For (GF)  \
# 2   Calgary Flames  1990    46      26        NaN  0.575             344
# 23  Calgary Flames  1991    31      37        NaN  0.388             296
# 27  Calgary Flames  1990    46      26        NaN  0.575             344
# 48  Calgary Flames  1991    31      37        NaN  0.388             296
#
#     Goals Against (GA)  + / -
# 2                  263     81
# 23                 305     -9
# 27                 263     81
# 48                 305     -9

# %%
df2=df.set_index('Year')
df2
# Out:
#                   Team Name  Wins  Losses  OT Losses  Win %  Goals For (GF)  \
# Year
# 1990          Boston Bruins    44      24        NaN  0.550             299
# 1990         Buffalo Sabres    31      30        NaN  0.388             292
# 1990         Calgary Flames    46      26        NaN  0.575             344
# 1990     Chicago Blackhawks    49      23        NaN  0.613             284
# 1990      Detroit Red Wings    34      38        NaN  0.425             273
# 1990        Edmonton Oilers    37      37        NaN  0.463             272
# 1990       Hartford Whalers    31      38        NaN  0.388             238
# 1990      Los Angeles Kings    46      24        NaN  0.575             340
# 1990  Minnesota North Stars    27      39        NaN  0.338             256
# 1990     Montreal Canadiens    39      30        NaN  0.487             273
# 1990      New Jersey Devils    32      33        NaN  0.400             272
# ...

# %%
df3=df2.filter(items=['Team Name', 'Wins', 'Losses', '+ / -'])
df3
# Out:
#                   Team Name  Wins  Losses  + / -
# Year
# 1990          Boston Bruins    44      24     35
# 1990         Buffalo Sabres    31      30     14
# 1990         Calgary Flames    46      26     81
# 1990     Chicago Blackhawks    49      23     73
# 1990      Detroit Red Wings    34      38    -25
# 1990        Edmonton Oilers    37      37      0
# 1990       Hartford Whalers    31      38    -38
# 1990      Los Angeles Kings    46      24     86
# 1990  Minnesota North Stars    27      39    -10
# 1990     Montreal Canadiens    39      30     24
# 1990      New Jersey Devils    32      33      8
# 1990     New York Islanders    25      45    -67
# 1990       New York Rangers    36      31     32
# 1990    Philadelphia Flyers    33      37    -15
# 1990    Pittsburgh Penguins    41      33     37
# 1990       Quebec Nordiques    16      50   -118
# 1990        St. Louis Blues    47      22     60
# 1990    Toronto Maple Leafs    23      46    -77
# ...

# %%
team_nad=['Montreal Canadiens', 'Calgary Flames']
df3[df3['Team Name'].isin(team_nad)]
# Out:
#                Team Name  Wins  Losses  + / -
# Year
# 1990      Calgary Flames    46      26     81
# 1990  Montreal Canadiens    39      30     24
# 1991      Calgary Flames    31      37     -9
# 1990      Calgary Flames    46      26     81
# 1990  Montreal Canadiens    39      30     24
# 1991      Calgary Flames    31      37     -9

# %%
df
# Out:
#                 Team Name  Year  Wins  Losses  OT Losses  Win %  \
# 0           Boston Bruins  1990    44      24        NaN  0.550
# 1          Buffalo Sabres  1990    31      30        NaN  0.388
# 2          Calgary Flames  1990    46      26        NaN  0.575
# 3      Chicago Blackhawks  1990    49      23        NaN  0.613
# 4       Detroit Red Wings  1990    34      38        NaN  0.425
# 5         Edmonton Oilers  1990    37      37        NaN  0.463
# 6        Hartford Whalers  1990    31      38        NaN  0.388
# 7       Los Angeles Kings  1990    46      24        NaN  0.575
# 8   Minnesota North Stars  1990    27      39        NaN  0.338
# 9      Montreal Canadiens  1990    39      30        NaN  0.487
# 10      New Jersey Devils  1990    32      33        NaN  0.400
# 11     New York Islanders  1990    25      45        NaN  0.312
# 12       New York Rangers  1990    36      31        NaN  0.450
# 13    Philadelphia Flyers  1990    33      37        NaN  0.412
# ...

# %%
df3[df3['Wins']>=47].sort_values(by='Wins', ascending=True)
# Out:
#                Team Name  Wins  Losses  + / -
# Year
# 1990     St. Louis Blues    47      22     60
# 1990     St. Louis Blues    47      22     60
# 1990  Chicago Blackhawks    49      23     73
# 1990  Chicago Blackhawks    49      23     73
