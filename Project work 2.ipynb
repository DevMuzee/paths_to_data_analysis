# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ABDULMUIZ AKOREDE\Downloads\Breast Cancer METABRIC.csv")
df.head()
# Out:
#   Patient ID  Age at Diagnosis Type of Breast Surgery    Cancer Type  \
# 0    MB-0000             75.65             Mastectomy  Breast Cancer
# 1    MB-0002             43.19      Breast Conserving  Breast Cancer
# 2    MB-0005             48.87             Mastectomy  Breast Cancer
# 3    MB-0006             47.68             Mastectomy  Breast Cancer
# 4    MB-0008             76.97             Mastectomy  Breast Cancer
#
#                         Cancer Type Detailed Cellularity Chemotherapy  \
# 0           Breast Invasive Ductal Carcinoma         NaN           No
# 1           Breast Invasive Ductal Carcinoma        High           No
# 2           Breast Invasive Ductal Carcinoma        High          Yes
# 3  Breast Mixed Ductal and Lobular Carcinoma    Moderate          Yes
# 4  Breast Mixed Ductal and Lobular Carcinoma        High          Yes
#
#   Pam50 + Claudin-low subtype  Cohort ER status measured by IHC ER Status  \
# 0                 claudin-low     1.0                   Positve  Positive
# 1                        LumA     1.0                   Positve  Positive
# 2                        LumB     1.0                   Positve  Positive
# 3                        LumB     1.0                   Positve  Positive
# 4                        LumB     1.0                   Positve  Positive
#
#    Neoplasm Histologic Grade HER2 status measured by SNP6 HER2 Status  \
# 0                        3.0                      Neutral    Negative
# 1                        3.0                      Neutral    Negative
# 2                        2.0                      Neutral    Negative
# 3                        2.0                      Neutral    Negative
# 4                        3.0                      Neutral    Negative
#
#   Tumor Other Histologic Subtype Hormone Therapy Inferred Menopausal State  \
# 0                     Ductal/NST             Yes                      Post
# 1                     Ductal/NST             Yes                       Pre
# 2                     Ductal/NST             Yes                       Pre
# 3                          Mixed             Yes                       Pre
# 4                          Mixed             Yes                      Post
#
#   Integrative Cluster Primary Tumor Laterality  Lymph nodes examined positive  \
# 0                4ER+                    Right                           10.0
# 1                4ER+                    Right                            0.0
# 2                   3                    Right                            1.0
# 3                   9                    Right                            3.0
# 4                   9                    Right                            8.0
#
#    Mutation Count  Nottingham prognostic index Oncotree Code  \
# 0             NaN                        6.044           IDC
# 1             2.0                        4.020           IDC
# 2             2.0                        4.030           IDC
# 3             1.0                        4.050          MDLC
# 4             2.0                        6.080          MDLC
#
#    Overall Survival (Months) Overall Survival Status PR Status Radio Therapy  \
# 0                 140.500000                  Living  Negative           Yes
# 1                  84.633333                  Living  Positive           Yes
# 2                 163.700000                Deceased  Positive            No
# 3                 164.933333                  Living  Positive           Yes
# 4                  41.366667                Deceased  Positive           Yes
#
#    Relapse Free Status (Months) Relapse Free Status     Sex  \
# 0                        138.65        Not Recurred  Female
# 1                         83.52        Not Recurred  Female
# 2                        151.28            Recurred  Female
# 3                        162.76        Not Recurred  Female
# 4                         18.55            Recurred  Female
#
#   3-Gene classifier subtype  Tumor Size  Tumor Stage Patient's Vital Status
# 0                 ER-/HER2-        22.0          2.0                 Living
# 1     ER+/HER2- High Prolif        10.0          1.0                 Living
# 2                       NaN        15.0          2.0        Died of Disease
# 3                       NaN        25.0          2.0                 Living
# 4     ER+/HER2- High Prolif        40.0          2.0        Died of Disease

# %%
pd.set_option('display.max.columns',34)

# %%
df=df.dropna()
missing_data=df.isnull().sum()
missing_data
# Out:
# Patient ID                        0
# Age at Diagnosis                  0
# Type of Breast Surgery            0
# Cancer Type                       0
# Cancer Type Detailed              0
# Cellularity                       0
# Chemotherapy                      0
# Pam50 + Claudin-low subtype       0
# Cohort                            0
# ER status measured by IHC         0
# ER Status                         0
# Neoplasm Histologic Grade         0
# HER2 status measured by SNP6      0
# HER2 Status                       0
# Tumor Other Histologic Subtype    0
# Hormone Therapy                   0
# Inferred Menopausal State         0
# Integrative Cluster               0
# Primary Tumor Laterality          0
# Lymph nodes examined positive     0
# Mutation Count                    0
# Nottingham prognostic index       0
# Oncotree Code                     0
# Overall Survival (Months)         0
# Overall Survival Status           0
# PR Status                         0
# Radio Therapy                     0
# Relapse Free Status (Months)      0
# Relapse Free Status               0
# Sex                               0
# 3-Gene classifier subtype         0
# Tumor Size                        0
# Tumor Stage                       0
# Patient's Vital Status            0
# dtype: int64

# %%
df.tail()
# Out:
#      Patient ID  Age at Diagnosis Type of Breast Surgery    Cancer Type  \
# 1697    MB-6232             71.22             Mastectomy  Breast Cancer
# 1698    MB-6233             70.65      Breast Conserving  Breast Cancer
# 1700    MB-6237             75.62             Mastectomy  Breast Cancer
# 1702    MB-6239             52.84      Breast Conserving  Breast Cancer
# 1743    MB-6346             63.20      Breast Conserving  Breast Cancer
#
#                            Cancer Type Detailed Cellularity Chemotherapy  \
# 1697  Breast Mixed Ductal and Lobular Carcinoma        High           No
# 1698  Breast Mixed Ductal and Lobular Carcinoma        High           No
# 1700           Breast Invasive Ductal Carcinoma        High           No
# 1702  Breast Mixed Ductal and Lobular Carcinoma        High          Yes
# 1743   Breast Invasive Mixed Mucinous Carcinoma        High           No
#
#      Pam50 + Claudin-low subtype  Cohort ER status measured by IHC ER Status  \
# 1697                        LumA     5.0                   Positve  Positive
# 1698                        LumB     5.0                   Positve  Positive
# 1700                       Basal     5.0                  Negative  Negative
# 1702                      Normal     5.0                   Positve  Positive
# 1743                        LumB     5.0                   Positve  Positive
#
#       Neoplasm Histologic Grade HER2 status measured by SNP6 HER2 Status  \
# 1697                        2.0                      Neutral    Negative
# 1698                        1.0                      Neutral    Negative
# 1700                        3.0                         Gain    Negative
# 1702                        2.0                      Neutral    Negative
# 1743                        2.0                      Neutral    Negative
#
#      Tumor Other Histologic Subtype Hormone Therapy Inferred Menopausal State  \
# 1697                          Mixed             Yes                      Post
# 1698                          Mixed              No                      Post
# 1700                     Ductal/NST              No                      Post
# 1702                          Mixed              No                      Post
# 1743                       Mucinous              No                      Post
#
#      Integrative Cluster Primary Tumor Laterality  \
# 1697                   3                     Left
# 1698                   8                     Left
# 1700                  10                    Right
# 1702                   8                    Right
# 1743                   8                    Right
#
#       Lymph nodes examined positive  Mutation Count  \
# 1697                            4.0            11.0
# 1698                            0.0             9.0
# 1700                            0.0             4.0
# 1702                            6.0             5.0
# 1743                            0.0             3.0
#
#       Nottingham prognostic index Oncotree Code  Overall Survival (Months)  \
# 1697                        5.060          MDLC                  85.000000
# 1698                        2.040          MDLC                 201.166667
# 1700                        4.040           IDC                 105.200000
# 1702                        5.040          MDLC                 200.333333
# 1743                        3.044          IMMC                 281.500000
#
#      Overall Survival Status PR Status Radio Therapy  \
# 1697                Deceased  Positive            No
# 1698                  Living  Positive           Yes
# 1700                Deceased  Negative            No
# 1702                  Living  Positive           Yes
# 1743                  Living  Positive           Yes
#
#       Relapse Free Status (Months) Relapse Free Status     Sex  \
# 1697                         83.88        Not Recurred  Female
# 1698                        198.52        Not Recurred  Female
# 1700                        103.82        Not Recurred  Female
# 1702                        197.70        Not Recurred  Female
# 1743                        277.80        Not Recurred  Female
#
#      3-Gene classifier subtype  Tumor Size  Tumor Stage Patient's Vital Status
# 1697      ER+/HER2- Low Prolif        30.0          2.0   Died of Other Causes
# 1698      ER+/HER2- Low Prolif        20.0          1.0                 Living
# 1700                 ER-/HER2-        20.0          1.0   Died of Other Causes
# 1702     ER+/HER2- High Prolif        20.0          2.0                 Living
# 1743     ER+/HER2- High Prolif        22.0          2.0                 Living
